# %% [markdown]
# # 03 - Patient Survival Validation
#
# Apply the cell-line-trained model to patient data and test whether predicted sensitivity explains survival.

# %% [markdown]
# ## Load cell-line model + patient data

# %% [markdown]
# ## Generate predicted sensitivity scores

# %% [markdown]
# ## Fit survival model against real outcomes

# %% [markdown]
# ## Adjust for clinical covariates (age, stage, performance status)

# %% [markdown]
# ## Results & discussion
