# %% [markdown]
# # 02 - Cell-Line Regression Model
#
# Train a regression model on cell-line mutation data to predict chemo sensitivity.

# %% [markdown]
# ## Load processed cell-line data

# %% [markdown]
# ## Train/test split

# %% [markdown]
# ## Train regression model

# %% [markdown]
# ## Evaluate model

# %% [markdown]
# ## Save model (models/cellline_regression_model.pt)
