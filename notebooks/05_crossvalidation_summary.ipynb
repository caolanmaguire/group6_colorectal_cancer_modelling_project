# %% [markdown]
# # 05 - Cross-Validation Summary
#
# Compare the cell-line-to-patient direction against the patient-to-cell-line direction, and summarise findings.

# %% [markdown]
# ## Load results from notebooks 03 & 04

# %% [markdown]
# ## Compare flagged mutations across directions

# %% [markdown]
# ## Summary figures

# %% [markdown]
# ## Conclusions
