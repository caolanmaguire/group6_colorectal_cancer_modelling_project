# %% [markdown]
# # 04 - Patient Cox Regression
#
# Fit a Cox regression directly on patient survival data to derive a patient-side risk signature.

# %% [markdown]
# ## Load processed patient data

# %% [markdown]
# ## Fit Cox proportional hazards model

# %% [markdown]
# ## Identify high-risk mutations

# %% [markdown]
# ## Save model (models/patient_cox_model.pt)
