# %% [markdown]
# # 01 - Data Preparation
#
# Load raw datasets, match identifiers across sources, and build the cell-line and patient feature tables used downstream.

# %% [markdown]
# ## Load raw data

# %% [markdown]
# ## Clean & match identifiers

# %% [markdown]
# ## Build cell-line feature table

# %% [markdown]
# ## Build patient feature table

# %% [markdown]
# ## Save processed tables
